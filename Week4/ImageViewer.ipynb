# %% [markdown]
# <a href="https://colab.research.google.com/github/Fizza-Rubab/CS432-GPU/blob/main/Week4/ImageViewer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

#read image from our github repo
# !wget -nc "https://cdn.pixabay.com/photo/2018/08/14/13/23/ocean-3605547__480.jpg"
# Out:
# --2023-02-03 06:56:12--  https://cdn.pixabay.com/photo/2018/08/14/13/23/ocean-3605547__480.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.37.244, 172.64.150.12, 2606:4700:4400::ac40:960c, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.37.244|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36599 (36K) [binary/octet-stream]
# Saving to: ‘ocean-3605547__480.jpg’
#
# ocean-3605547__480. 100%[===================>]  35.74K  --.-KB/s    in 0s
#
# 2023-02-03 06:56:12 (90.7 MB/s) - ‘ocean-3605547__480.jpg’ saved [36599/36599]

# %%
#image exists, lets read it using opencv
img = cv2.imread("/content/ocean-3605547__480.jpg")

#display image using cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=740x480 at 0x7F06800EA730>
